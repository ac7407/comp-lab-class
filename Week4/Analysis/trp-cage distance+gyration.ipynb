# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md

# load xtc file
traj = md.load_xtc('fit_trp-cage.xtc', top='step5_9.gro')

# plot end-end distance vs time
plt.plot(traj.time, md.compute_distances(traj, [[0, 1]]))
plt.xlabel('Time (ps)')
plt.ylabel('Distance (nm)')
plt.title('end to end distance (nm) vs time (ps)')
plt.show()

# %%
# plot radius of gyration vs time
plt.plot(traj.time, md.compute_rg(traj))
plt.xlabel('Time (ps)')
plt.ylabel('Radius of gyration (nm)')
plt.title('Radius of gyration (nm) vs time (ps)')
plt.show()
